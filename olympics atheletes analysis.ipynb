# %%
import numpy as np
import pandas as pd
import matplotlib as pyplot

# %%
data=pd.read_csv('athlete_events.csv')
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
data.shape
# Out:
# (271116, 15)

# %%
# Fill missing values with the previous value
data.fillna(method='ffill', inplace=True)
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0   170.0    60.0
# 3            4      Edgar Lindenau Aabye   M  34.0   170.0    60.0
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('athlete_events.csv')
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data['Medal']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3         Gold
# 4          NaN
#           ...
# 271111     NaN
# 271112     NaN
# 271113     NaN
# 271114     NaN
# 271115     NaN
# Name: Medal, Length: 271116, dtype: object

# %%
data.iloc[:,[1,7,14]]
# Out:
#                             Name  NOC Medal
# 0                      A Dijiang  CHN   NaN
# 1                       A Lamusi  CHN   NaN
# 2            Gunnar Nielsen Aaby  DEN   NaN
# 3           Edgar Lindenau Aabye  DEN  Gold
# 4       Christine Jacoba Aaftink  NED   NaN
# ...                          ...  ...   ...
# 271111                Andrzej ya  POL   NaN
# 271112                  Piotr ya  POL   NaN
# 271113                  Piotr ya  POL   NaN
# 271114        Tomasz Ireneusz ya  POL   NaN
# 271115        Tomasz Ireneusz ya  POL   NaN
#
# [271116 rows x 3 columns]

# %%
mask1=data['Medal']=='Gold'

data[mask1]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %%
#this shows that total number of gold ,silver and bronze medal won from 1896 to 2016
data['Medal'].value_counts()
# Out:
# Medal
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: count, dtype: int64

# %%
#total number of male and female players
data['Sex'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Sex'>

# %%
#these are the top 5 cities where olympics were held
import seaborn as sns
data['City'].value_counts().head(5).plot(kind='barh')
# Out:
# City
# London            22426
# Athina            15556
# Sydney            13821
# Atlanta           13780
# Rio de Janeiro    13688
# Name: count, dtype: int64

# %%
#this means there is total 42 cities where olympics were held
data.drop_duplicates(subset=['City']).shape
# Out:
# (42, 15)

# %%
#a total of 230 countries have participates till 2016
data.drop_duplicates(subset=['NOC'])
# Out:
#           ID                        Name Sex   Age  Height  Weight  \
# 0          1                   A Dijiang   M  24.0   180.0    80.0
# 2          3         Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 4          5    Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 10         6             Per Knut Aaland   M  31.0   188.0    75.0
# 28         9            Antti Sami Aalto   M  26.0   186.0    96.0
# ...      ...                         ...  ..   ...     ...     ...
# 64674  33094                 Logona Esau   M  21.0   163.0    69.0
# 71806  36547  Robert Arthur "Bob" Fowler   M  21.0   170.0    57.0
# 80081  40647                Nora Gjakova   F  23.0   165.0    57.0
# 91746  46491              Margret Hassan   F  18.0   160.0    55.0
# 96572  48896               Kenneth Hlasa   M  25.0   170.0    67.0
#
#                 Team  NOC        Games  Year  Season            City  \
# 0              China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data['Team']
# Out:
# 0                  China
# 1                  China
# 2                Denmark
# 3         Denmark/Sweden
# 4            Netherlands
#                ...
# 271111          Poland-1
# 271112            Poland
# 271113            Poland
# 271114            Poland
# 271115            Poland
# Name: Team, Length: 271116, dtype: object

# %%
data.sort_values('Year',ascending=True).drop_duplicates(subset='City')[['Year','City']]
#this shows that in which year which olympics was held
# Out:
#         Year                    City
# 214333  1896                  Athina
# 257686  1900                   Paris
# 243548  1904               St. Louis
# 26677   1908                  London
# 178447  1912               Stockholm
# 263638  1920               Antwerpen
# 209810  1924                Chamonix
# 178578  1928               Amsterdam
# 28759   1928            Sankt Moritz
# 245339  1932             Los Angeles
# 228833  1932             Lake Placid
# 110857  1936                  Berlin
# 124711  1936  Garmisch-Partenkirchen
# 111638  1952                Helsinki
# 73830   1952                    Oslo
# 219578  1956               Melbourne
# 7730    1956       Cortina d'Ampezzo
# 196760  1960                    Roma
# 102137  1960            Squaw Valley
# 258399  1964                   Tokyo
# 85465   1964               Innsbruck
# 128506  1968                Grenoble
# 28034   1968             Mexico City
# 253680  1972                  Munich
# ...

# %%
#this shows the all types of sports played in olympics which is 66
data.drop_duplicates(subset='Sport')['Sport'].shape
# Out:
# (66,)

# %%
#hence we can see the maximum age group lie between 20-30
plt.hist(data['Age'],bins=[10,20,30,40,50,60,70,80])
# Out:
# (array([3.23030e+04, 1.77744e+05, 4.26840e+04, 6.69500e+03, 1.55800e+03,
#         5.29000e+02, 1.21000e+02]),
#  array([10., 20., 30., 40., 50., 60., 70., 80.]),
#  <BarContainer object of 7 artists>)

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#top 5 maximum number of gold medals won by any country from 1896 to 2016
mask1=data['Medal']=='Gold'

data[mask1].value_counts('Team').head(5).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
mask1=data['Medal']=='Bronze'

data[mask1].value_counts('Team').head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='Team'>

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data[['Height','Weight','Year']].sort_values('Year',ascending=True).dropna(subset=['Height']).drop_duplicates(subset='Height')
# Out:
#         Height  Weight  Year
# 75128    154.0    45.0  1896
# 47375    176.0    66.0  1896
# 32334    183.0    66.0  1896
# 42249    180.0     NaN  1896
# 105834   173.0    69.0  1896
# ...        ...     ...   ...
# 47982    217.0   106.0  1988
# 180615   128.0    74.0  1988
# 17669    221.0   114.0  1992
# 265040   226.0   141.0  2000
# 196667   219.0   113.0  2004
#
# [95 rows x 3 columns]

# %%
import seaborn as sns

# %%
data1=data[['Height','Weight','Year']].sort_values('Year',ascending=True).dropna(subset=['Height']).drop_duplicates(subset='Height')

# %%
plt.scatter(data1['Year'],data1['Height'],color='green',label='Height')
plt.scatter(data1['Year'],data1['Weight'],color='black',label='Weight')
plt.title('Height and Weight distribution over the years')
plt.xlabel('years')
plt.ylabel('height and weight')
plt.legend()

# %%
medal_data = data[data['Medal'].notna()]

# %%
medals_by_year = medal_data.groupby('Year').size()

# %%
plt.figure(figsize=(10, 6))
plt.plot(medals_by_year.index, medals_by_year.values, marker='o', linestyle='-', color='b')
plt.title('Number of Medals Won by Athletes Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.grid(True)
plt.show()

# %%
data.value_counts('Season').plot(kind='barh')
# Out:
# <Axes: ylabel='Season'>
